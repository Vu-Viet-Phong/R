# %% [markdown]
# # [Decision Tree](https://en.wikipedia.org/wiki/Decision_tree)

# %% [markdown]
# A decision tree is a decision support tool that uses a tree-like model of decisions and their possible consequences, including chance event outcomes, resource costs, and utility. It is one way to display an algorithm that only contains conditional control statements.

# %%
library(party)

# %% [markdown]
# ## Input

# %%
# Print some records from data set readingSkills.
print(head(readingSkills))
# Out:
#   nativeSpeaker age shoeSize    score
# 1           yes   5 24.83189 32.29385
# 2           yes   6 25.95238 36.63105
# 3            no  11 30.42170 49.60593
# 4           yes   7 28.66450 40.28456
# 5           yes  11 31.88207 55.46085
# 6           yes  10 30.07843 52.83124

# %% [markdown]
# ### Use the ctree() function to create the decision tree and see its graph

# %%
# Create a input data frame.
df = readingSkills[c(1:105),]

# Create the tree
tree <- ctree(nativeSpeaker ~ age + shoeSize + score, data = df)

# Plot the tree
plot(tree)
# Out:
# plot without title

# %% [markdown]
# `Conclusion:` anyone whose readingSkills score is less than 38.3 and age is more than 6 is not a native Speaker.
